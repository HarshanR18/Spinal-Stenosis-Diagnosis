# %%
import pydicom
import glob, os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2
from tqdm import tqdm
import re
import shutil
import os

# %%
rd ='/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification'
rs='/kaggle/working'

# %%
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# %%
dfc = pd.read_csv(f'{rd}/train_label_coordinates.csv')
df = pd.read_csv(f'{rd}/train_series_descriptions.csv')
df.head()
# Out:
#    study_id   series_id series_description
# 0   4003253   702807833   Sagittal T2/STIR
# 1   4003253  1054713880        Sagittal T1
# 2   4003253  2448190387           Axial T2
# 3   4646740  3201256954           Axial T2
# 4   4646740  3486248476        Sagittal T1

# %%
shutil.copy(f"{rd}/train_label_coordinates.csv", rs)
shutil.copy(f"{rd}/train_series_descriptions.csv", rs)
print("File moved to output directory.")
# Out:
# File moved to output directory.

# %%
dft = pd.read_csv(f'{rd}/train.csv')
dft = dft.iloc[:500]
dft.to_csv(f'{rs}/train_500.csv', index=False)

# %%
import os
import pandas as pd

def filter_study_ids(primary_csv, target_directory):

    # Ensure primary CSV file exists
    if not os.path.exists(primary_csv):
        print(f"Error: {primary_csv} not found. Skipping processing.")
        return

    # Load primary CSV and extract study_id values
    primary_df = pd.read_csv(primary_csv)

    if 'study_id' not in primary_df.columns:
        print(f"Error: 'study_id' column not found in {primary_csv}.")
        return

    # Identify missing and valid study_id values
    missing_study_ids = primary_df[primary_df.isna().any(axis=1)]['study_id'].unique()
    valid_study_ids = primary_df['study_id'].unique()

    print(f"Filtering CSV files in {target_directory}...")
    print(f"- Removing {len(missing_study_ids)} missing study_id values")
    print(f"- Keeping {len(valid_study_ids)} valid study_id values")

    # Process each CSV file in the target directory
    for filename in os.listdir(target_directory):
        if filename.endswith('.csv'):
            file_path = os.path.join(target_directory, filename)

            try:
                df = pd.read_csv(file_path)

                if 'study_id' in df.columns:
                    # Remove rows with missing study_id values & keep only valid ones
                    df_filtered = df[~df['study_id'].isin(missing_study_ids)]
                    df_filtered = df_filtered[df_filtered['study_id'].isin(valid_study_ids)]
                    
                    df_filtered.to_csv(file_path, index=False)
                    print(f"Updated {filename}: Removed {len(df) - len(df_filtered)} rows, kept valid study_id values.")
                else:
                    print(f"Warning: 'study_id' column not found in {filename}. Skipping this file.")

            except Exception as e:
                print(f"Error processing {filename}: {e}")

# Define file paths
primary_csv = f'{rs}/train_500.csv'
target_directory = '/kaggle/working/'

# Run the filtering process
filter_study_ids(primary_csv, target_directory)
# Out:
# Filtering CSV files in /kaggle/working/...
# - Removing 42 missing study_id values
# - Keeping 500 valid study_id values
# Updated train_label_coordinates.csv: Removed 37246 rows, kept valid study_id values.
# Updated train_500.csv: Removed 42 rows, kept valid study_id values.
# Updated train_series_descriptions.csv: Removed 4826 rows, kept valid study_id values.

# %%
dfts=pd.read_csv(f'{rs}/train_series_descriptions.csv')
dfts
# Out:
#         study_id   series_id series_description
# 0        4003253   702807833   Sagittal T2/STIR
# 1        4003253  1054713880        Sagittal T1
# 2        4003253  2448190387           Axial T2
# 3        4646740  3201256954           Axial T2
# 4        4646740  3486248476        Sagittal T1
# ...          ...         ...                ...
# 1463  1099112122   919181265        Sagittal T1
# 1464  1099112122  1815821295   Sagittal T2/STIR
# 1465  1103373889  1437983577   Sagittal T2/STIR
# 1466  1103373889  1669196197        Sagittal T1
# 1467  1103373889  4018431347           Axial T2
#
# [1468 rows x 3 columns]

# %%
dfts['series_description'].value_counts()
# Out:
# series_description
# Axial T2            551
# Sagittal T1         459
# Sagittal T2/STIR    458
# Name: count, dtype: int64

# %%
def imread_and_imwirte(src_path, dst_path):
    dicom_data = pydicom.dcmread(src_path)
    image = dicom_data.pixel_array
    image = (image - image.min()) / (image.max() - image.min() +1e-6) * 255
    img = cv2.resize(image, (512, 512),interpolation=cv2.INTER_CUBIC)
    assert img.shape==(512,512)
    cv2.imwrite(dst_path, img)

# %%
st_ids= dfts['study_id'].unique()
st_ids[:3], len(st_ids)
# Out:
# (array([4003253, 4646740, 7143189]), 458)

# %%
desc = list(dfts['series_description'].unique())
desc
# Out:
# ['Sagittal T2/STIR', 'Sagittal T1', 'Axial T2']

# %%
for idx, si in enumerate(tqdm(st_ids, total=len(st_ids))):
    pdf = dfts[dfts['study_id']==si]
    for ds in desc:
        ds_ = ds.replace('/', '_')
        pdf_ = pdf[pdf['series_description']==ds]
        os.makedirs(f'mri_png/{si}/{ds_}', exist_ok=True)
        allimgs = []
        for i, row in pdf_.iterrows():
            pimgs = glob.glob(f'{rd}/train_images/{row["study_id"]}/{row["series_id"]}/*.dcm')
            pimgs = sorted(pimgs, key=natural_keys)
            allimgs.extend(pimgs)
            
        if len(allimgs)==0:
            print(si, ds, 'has no images')
            continue

        if ds == 'Axial T2':
            for j, impath in enumerate(allimgs):
                dst = f'mri_png/{si}/{ds}/{j:03d}.png'
                imread_and_imwirte(impath, dst)
                
        elif ds == 'Sagittal T2/STIR':
            
            step = len(allimgs) / 10.0
            st = len(allimgs)/2.0 - 4.0*step
            end = len(allimgs)+0.0001
            for j, i in enumerate(np.arange(st, end, step)):
                dst = f'mri_png/{si}/{ds_}/{j:03d}.png'
                ind2 = max(0, int((i-0.5001).round()))
                imread_and_imwirte(allimgs[ind2], dst)
                
            assert len(glob.glob(f'mri_png/{si}/{ds_}/*.png'))==10
                
        elif ds == 'Sagittal T1':
            step = len(allimgs) / 10.0
            st = len(allimgs)/2.0 - 4.0*step
            end = len(allimgs)+0.0001
            for j, i in enumerate(np.arange(st, end, step)):
                dst = f'mri_png/{si}/{ds}/{j:03d}.png'
                ind2 = max(0, int((i-0.5001).round()))
                imread_and_imwirte(allimgs[ind2], dst)
                
            assert len(glob.glob(f'mri_png/{si}/{ds}/*.png'))==10
# Out:
# 100%|██████████| 458/458 [10:03<00:00,  1.32s/it]

# %%
# !zip -r /kaggle/working/output.zip /kaggle/working/
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/mri_png/ (stored 0%)
#   adding: kaggle/working/mri_png/597752094/ (stored 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T1/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T1/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T1/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T1/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T1/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T1/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T1/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T1/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T1/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T1/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T2_STIR/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T2_STIR/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T2_STIR/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T2_STIR/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T2_STIR/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T2_STIR/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T2_STIR/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T2_STIR/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Sagittal T2_STIR/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/020.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/021.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/010.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/018.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/014.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/011.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/012.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/016.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/013.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/015.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/019.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/017.png (deflated 0%)
#   adding: kaggle/working/mri_png/597752094/Axial T2/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/ (stored 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T1/008.png (deflated 1%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T1/007.png (deflated 1%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T1/001.png (deflated 1%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T1/005.png (deflated 1%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T1/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T1/009.png (deflated 1%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T1/004.png (deflated 1%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T1/000.png (deflated 1%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T1/003.png (deflated 1%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T1/006.png (deflated 1%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T2_STIR/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T2_STIR/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T2_STIR/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T2_STIR/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T2_STIR/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T2_STIR/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T2_STIR/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T2_STIR/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Sagittal T2_STIR/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/030.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/020.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/035.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/024.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/021.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/010.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/028.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/018.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/033.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/036.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/027.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/014.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/034.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/011.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/012.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/016.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/013.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/015.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/032.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/023.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/022.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/026.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/025.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/019.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/017.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/031.png (deflated 0%)
#   adding: kaggle/working/mri_png/71973234/Axial T2/029.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/ (stored 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T1/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T1/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T1/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T1/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T1/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T1/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T1/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T1/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T1/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T1/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T2_STIR/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T2_STIR/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T2_STIR/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T2_STIR/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T2_STIR/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T2_STIR/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T2_STIR/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T2_STIR/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Sagittal T2_STIR/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/020.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/021.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/010.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/018.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/014.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/011.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/012.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/016.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/013.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/015.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/022.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/019.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/017.png (deflated 0%)
#   adding: kaggle/working/mri_png/764520264/Axial T2/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/757619082/ (stored 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T1/008.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T1/007.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T1/001.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T1/005.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T1/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T1/009.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T1/004.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T1/000.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T1/003.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T1/006.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T2_STIR/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T2_STIR/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T2_STIR/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T2_STIR/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T2_STIR/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T2_STIR/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T2_STIR/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T2_STIR/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/757619082/Sagittal T2_STIR/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/008.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/020.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/024.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/021.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/007.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/010.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/018.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/001.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/014.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/011.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/005.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/012.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/016.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/013.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/009.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/015.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/004.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/000.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/023.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/022.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/003.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/019.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/017.png (deflated 1%)
#   adding: kaggle/working/mri_png/757619082/Axial T2/006.png (deflated 1%)
#   adding: kaggle/working/mri_png/674762852/ (stored 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T1/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T1/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T1/001.png (deflated 1%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T1/005.png (deflated 1%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T1/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T1/009.png (deflated 1%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T1/004.png (deflated 1%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T1/000.png (deflated 1%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T1/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T1/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T2_STIR/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T2_STIR/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T2_STIR/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T2_STIR/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T2_STIR/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T2_STIR/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T2_STIR/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T2_STIR/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Sagittal T2_STIR/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/020.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/024.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/021.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/010.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/018.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/014.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/011.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/012.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/016.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/013.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/015.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/023.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/022.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/019.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/017.png (deflated 0%)
#   adding: kaggle/working/mri_png/674762852/Axial T2/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/ (stored 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T1/008.png (deflated 1%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T1/007.png (deflated 1%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T1/001.png (deflated 1%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T1/005.png (deflated 1%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T1/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T1/009.png (deflated 1%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T1/004.png (deflated 1%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T1/000.png (deflated 1%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T1/003.png (deflated 1%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T1/006.png (deflated 1%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T2_STIR/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T2_STIR/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T2_STIR/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T2_STIR/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T2_STIR/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T2_STIR/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T2_STIR/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T2_STIR/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Sagittal T2_STIR/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/020.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/024.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/021.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/010.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/018.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/014.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/011.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/012.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/016.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/013.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/015.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/023.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/022.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/025.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/019.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/017.png (deflated 0%)
#   adding: kaggle/working/mri_png/806480418/Axial T2/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/ (stored 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T1/008.png (deflated 1%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T1/007.png (deflated 1%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T1/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T1/005.png (deflated 1%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T1/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T1/009.png (deflated 1%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T1/004.png (deflated 1%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T1/000.png (deflated 1%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T1/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T1/006.png (deflated 1%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T2_STIR/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T2_STIR/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T2_STIR/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T2_STIR/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T2_STIR/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T2_STIR/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T2_STIR/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T2_STIR/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Sagittal T2_STIR/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/080.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/064.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/045.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/030.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/099.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/073.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/084.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/020.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/071.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/075.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/035.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/086.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/041.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/024.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/060.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/061.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/021.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/046.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/047.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/010.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/089.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/070.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/081.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/096.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/028.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/092.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/059.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/077.png (deflated 1%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/018.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/069.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/066.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/033.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/036.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/042.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/027.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/079.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/014.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/034.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/095.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/058.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/011.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/012.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/037.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/052.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/090.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/016.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/088.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/044.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/097.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/091.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/013.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/076.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/062.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/057.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/063.png (deflated 1%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/048.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/015.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/074.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/051.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/083.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/072.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/056.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/032.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/054.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/098.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/067.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/050.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/065.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/023.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/022.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/026.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/053.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/055.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/093.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/082.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/085.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/094.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/078.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/068.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/039.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/038.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/025.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/043.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/087.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/040.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/019.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/017.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/031.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/029.png (deflated 0%)
#   adding: kaggle/working/mri_png/105895264/Axial T2/049.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/ (stored 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T1/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T1/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T1/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T1/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T1/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T1/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T1/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T1/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T1/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T1/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T2_STIR/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T2_STIR/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T2_STIR/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T2_STIR/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T2_STIR/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T2_STIR/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T2_STIR/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T2_STIR/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Sagittal T2_STIR/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/045.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/030.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/020.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/035.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/041.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/024.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/021.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/046.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/047.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/010.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/028.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/059.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/018.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/033.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/036.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/042.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/027.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/014.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/034.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/058.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/011.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/012.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/037.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/052.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/016.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/044.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/013.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/057.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/048.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/015.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/051.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/056.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/032.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/054.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/050.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/023.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/022.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/026.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/053.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/055.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/039.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/038.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/025.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/043.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/040.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/019.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/017.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/031.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/029.png (deflated 0%)
#   adding: kaggle/working/mri_png/100206310/Axial T2/049.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/ (stored 0%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T1/008.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T1/007.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T1/001.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T1/005.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T1/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T1/009.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T1/004.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T1/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T1/003.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T1/006.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T2_STIR/008.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T2_STIR/007.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T2_STIR/001.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T2_STIR/005.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T2_STIR/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T2_STIR/009.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T2_STIR/000.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T2_STIR/003.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Sagittal T2_STIR/006.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/080.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/064.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/045.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/030.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/008.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/073.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/084.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/020.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/071.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/075.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/035.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/086.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/041.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/024.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/060.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/061.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/021.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/046.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/047.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/007.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/010.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/089.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/070.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/081.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/028.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/059.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/077.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/018.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/069.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/001.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/066.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/033.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/036.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/042.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/027.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/079.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/014.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/034.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/058.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/011.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/005.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/012.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/037.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/052.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/090.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/016.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/088.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/044.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/091.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/013.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/076.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/062.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/009.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/057.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/063.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/048.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/015.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/074.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/051.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/004.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/083.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/000.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/072.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/056.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/032.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/054.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/067.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/050.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/065.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/023.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/022.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/026.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/053.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/055.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/082.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/085.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/078.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/068.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/039.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/038.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/025.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/043.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/087.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/040.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/003.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/019.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/017.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/006.png (deflated 1%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/031.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/029.png (deflated 0%)
#   adding: kaggle/working/mri_png/886995462/Axial T2/049.png (deflated 0%)
#   adding: kaggle/working/mri_png/153831832/ (stored 0%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T1/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T1/007.png (deflated 1%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T1/001.png (deflated 1%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T1/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T1/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T1/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T1/004.png (deflated 1%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T1/000.png (deflated 1%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T1/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T1/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/153831832/Sagittal T2_STIR/ (stored 0%)
# ...
#   adding: kaggle/working/mri_png/86250890/Axial T2/040.png (deflated 0%)
#   adding: kaggle/working/mri_png/86250890/Axial T2/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/86250890/Axial T2/019.png (deflated 0%)
#   adding: kaggle/working/mri_png/86250890/Axial T2/017.png (deflated 0%)
#   adding: kaggle/working/mri_png/86250890/Axial T2/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/86250890/Axial T2/031.png (deflated 0%)
#   adding: kaggle/working/mri_png/86250890/Axial T2/029.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/ (stored 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T1/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T1/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T1/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T1/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T1/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T1/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T1/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T1/000.png (deflated 1%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T1/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T1/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T2_STIR/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T2_STIR/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T2_STIR/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T2_STIR/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T2_STIR/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T2_STIR/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T2_STIR/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T2_STIR/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Sagittal T2_STIR/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/045.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/030.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/020.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/035.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/041.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/024.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/021.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/046.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/047.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/010.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/028.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/018.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/033.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/036.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/042.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/027.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/014.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/034.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/011.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/012.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/037.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/052.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/016.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/044.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/013.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/048.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/015.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/051.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/032.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/050.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/023.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/022.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/026.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/039.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/038.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/025.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/043.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/040.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/019.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/017.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/031.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/029.png (deflated 0%)
#   adding: kaggle/working/mri_png/113121178/Axial T2/049.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/ (stored 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T1/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T1/007.png (deflated 1%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T1/001.png (deflated 1%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T1/005.png (deflated 1%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T1/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T1/009.png (deflated 1%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T1/004.png (deflated 1%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T1/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T1/003.png (deflated 1%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T1/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T2_STIR/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T2_STIR/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T2_STIR/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T2_STIR/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T2_STIR/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T2_STIR/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T2_STIR/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T2_STIR/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Sagittal T2_STIR/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/020.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/021.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/010.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/018.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/014.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/011.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/012.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/016.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/013.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/015.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/019.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/017.png (deflated 0%)
#   adding: kaggle/working/mri_png/110271740/Axial T2/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/ (stored 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T1/ (stored 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T1/008.png (deflated 1%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T1/007.png (deflated 1%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T1/001.png (deflated 1%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T1/005.png (deflated 1%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T1/002.png (deflated 1%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T1/009.png (deflated 1%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T1/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T1/000.png (deflated 1%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T1/003.png (deflated 1%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T1/006.png (deflated 1%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T2_STIR/ (stored 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T2_STIR/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T2_STIR/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T2_STIR/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T2_STIR/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T2_STIR/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T2_STIR/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T2_STIR/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T2_STIR/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T2_STIR/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Sagittal T2_STIR/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/ (stored 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/045.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/030.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/008.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/020.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/035.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/041.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/024.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/021.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/046.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/047.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/007.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/010.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/028.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/018.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/001.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/033.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/036.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/042.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/027.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/014.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/034.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/011.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/005.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/012.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/037.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/052.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/016.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/002.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/044.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/013.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/009.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/048.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/015.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/051.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/004.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/000.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/032.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/054.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/050.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/023.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/022.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/026.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/053.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/039.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/038.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/025.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/043.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/040.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/003.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/019.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/017.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/006.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/031.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/029.png (deflated 0%)
#   adding: kaggle/working/mri_png/349723373/Axial T2/049.png (deflated 0%)
#   adding: kaggle/working/train_label_coordinates.csv (deflated 76%)
#   adding: kaggle/working/train_500.csv (deflated 95%)
#   adding: kaggle/working/train_series_descriptions.csv (deflated 70%)
#   adding: kaggle/working/__notebook__.ipynb (deflated 96%)
